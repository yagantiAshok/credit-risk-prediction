# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("cs-training.csv")

# %%
data
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 0                1                 1                              0.766127
# 1                2                 0                              0.957151
# 2                3                 0                              0.658180
# 3                4                 0                              0.233810
# 4                5                 0                              0.907239
# ...            ...               ...                                   ...
# 149995      149996                 0                              0.040674
# 149996      149997                 0                              0.299745
# 149997      149998                 0                              0.246044
# 149998      149999                 0                              0.000000
# 149999      150000                 0                              0.850283
#
# ...

# %%
list(data.columns)
# Out:
# ['SeriousDlqin2yrs',
#  'RevolvingUtilizationOfUnsecuredLines',
#  'age',
#  'NumberOfTime30-59DaysPastDueNotWorse',
#  'DebtRatio',
#  'MonthlyIncome',
#  'NumberOfOpenCreditLinesAndLoans',
#  'NumberOfTimes90DaysLate',
#  'NumberRealEstateLoansOrLines',
#  'NumberOfTime60-89DaysPastDueNotWorse',
#  'NumberOfDependents']

# %%
list(data.columns)
# Out:
# ['Unnamed: 0',
#  'SeriousDlqin2yrs',
#  'RevolvingUtilizationOfUnsecuredLines',
#  'age',
#  'NumberOfTime30-59DaysPastDueNotWorse',
#  'DebtRatio',
#  'MonthlyIncome',
#  'NumberOfOpenCreditLinesAndLoans',
#  'NumberOfTimes90DaysLate',
#  'NumberRealEstateLoansOrLines',
#  'NumberOfTime60-89DaysPastDueNotWorse',
#  'NumberOfDependents']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Unnamed: 0                            150000 non-null  int64
#  1   SeriousDlqin2yrs                      150000 non-null  int64
#  2   RevolvingUtilizationOfUnsecuredLines  150000 non-null  float64
#  3   age                                   150000 non-null  int64
#  4   NumberOfTime30-59DaysPastDueNotWorse  150000 non-null  int64
#  5   DebtRatio                             150000 non-null  float64
#  6   MonthlyIncome                         120269 non-null  float64
#  7   NumberOfOpenCreditLinesAndLoans       150000 non-null  int64
#  8   NumberOfTimes90DaysLate               150000 non-null  int64
#  9   NumberRealEstateLoansOrLines          150000 non-null  int64
# ...

# %%
ty = data["NumberOfDependents"].dtype

# %%
str(ty)
# Out:
# 'float64'

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # data quality analysis

# %%
data.shape
# Out:
# (150000, 12)

# %%
data.head()
# Out:
#    Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0           1                 1                              0.766127   45
# 1           2                 0                              0.957151   40
# 2           3                 0                              0.658180   38
# 3           4                 0                              0.233810   30
# 4           5                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# ...

# %%
data.drop("Unnamed: 0",axis=1,inplace=True)

# %%
data.head()
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                 1                              0.766127   45
# 1                 0                              0.957151   40
# 2                 0                              0.658180   38
# 3                 0                              0.233810   30
# 4                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                               13                        0
# 1                                4                        0
# ...

# %%
data.isnull().sum()
# Out:
# SeriousDlqin2yrs                            0
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# NumberOfTime30-59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                           29731
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60-89DaysPastDueNotWorse        0
# NumberOfDependents                       3924
# dtype: int64

# %%
data[data.duplicated()]
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 1669                   0                                   1.0   29
# 7823                   0                                   1.0   29
# 7920                   0                                   1.0   22
# 8840                   0                                   1.0   23
# 10869                  0                                   1.0   73
# ...                  ...                                   ...  ...
# 149139                 0                                   0.0   77
# 149431                 0                                   1.0   25
# 149472                 0                                   1.0   84
# 149769                 0                                   1.0   23
# 149993                 0                                   1.0   22
#
#         NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 1669                                       0        0.0            NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   SeriousDlqin2yrs                      150000 non-null  int64
#  1   RevolvingUtilizationOfUnsecuredLines  150000 non-null  float64
#  2   age                                   150000 non-null  int64
#  3   NumberOfTime30-59DaysPastDueNotWorse  150000 non-null  int64
#  4   DebtRatio                             150000 non-null  float64
#  5   MonthlyIncome                         120269 non-null  float64
#  6   NumberOfOpenCreditLinesAndLoans       150000 non-null  int64
#  7   NumberOfTimes90DaysLate               150000 non-null  int64
#  8   NumberRealEstateLoansOrLines          150000 non-null  int64
#  9   NumberOfTime60-89DaysPastDueNotWorse  150000 non-null  int64
# ...

# %%
# nan values are present 
# duplicate values are present
# no datatype mismatch

# %% [markdown]
# # descriptive statistics

# %%
data.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count     150000.000000                         150000.000000  150000.000000
# mean           0.066840                              6.048438      52.295207
# std            0.249746                            249.755371      14.771866
# min            0.000000                              0.000000       0.000000
# 25%            0.000000                              0.029867      41.000000
# 50%            0.000000                              0.154181      52.000000
# 75%            0.000000                              0.559046      63.000000
# max            1.000000                          50708.000000     109.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         150000.000000  150000.000000   1.202690e+05
# mean                               0.421033     353.005076   6.670221e+03
# ...

# %%
data["RevolvingUtilizationOfUnsecuredLines"].describe()
# Out:
# count    150000.000000
# mean          6.048438
# std         249.755371
# min           0.000000
# 25%           0.029867
# 50%           0.154181
# 75%           0.559046
# max       50708.000000
# Name: RevolvingUtilizationOfUnsecuredLines, dtype: float64

# %%
data[data["RevolvingUtilizationOfUnsecuredLines"]>1]
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 162                    1                              1.046279   47
# 191                    0                              1.095083   53
# 226                    1                              1.953488   38
# 251                    1                              1.048211   58
# 293                    0                           2340.000000   45
# ...                  ...                                   ...  ...
# 149939                 0                              1.049900   26
# 149955                 1                              1.135552   41
# 149962                 0                              1.005733   48
# 149964                 0                              1.010934   63
# 149973                 0                              1.026395   44
#
#         NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 162                                        1   1.104301         5416.0
# ...

# %%
data.head()
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                 1                              0.766127   45
# 1                 0                              0.957151   40
# 2                 0                              0.658180   38
# 3                 0                              0.233810   30
# 4                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                               13                        0
# 1                                4                        0
# ...

# %%
data
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                      1                              0.766127   45
# 1                      0                              0.957151   40
# 2                      0                              0.658180   38
# 3                      0                              0.233810   30
# 4                      0                              0.907239   49
# ...                  ...                                   ...  ...
# 149995                 0                              0.040674   74
# 149996                 0                              0.299745   44
# 149997                 0                              0.246044   58
# 149998                 0                              0.000000   30
# 149999                 0                              0.850283   64
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 0                                          2     0.802982         9120.0
# ...

# %%
dic = data.to_dict(orient='records')

# %%
dic[1]
# Out:
# {'SeriousDlqin2yrs': 0,
#  'RevolvingUtilizationOfUnsecuredLines': 0.957151019,
#  'age': 40,
#  'NumberOfTime30-59DaysPastDueNotWorse': 0,
#  'DebtRatio': 0.121876201,
#  'MonthlyIncome': 2600.0,
#  'NumberOfOpenCreditLinesAndLoans': 4,
#  'NumberOfTimes90DaysLate': 0,
#  'NumberRealEstateLoansOrLines': 0,
#  'NumberOfTime60-89DaysPastDueNotWorse': 0,
#  'NumberOfDependents': 1.0}

# %%
import pymongo

# %%
# client = pymongo.MongoClient(mongodb_server)
# db = client["credit-risk-customers"]
# collection = db["cutomers"]
# # collection.insert_many(dic)

# %%
row = collection.find()

# %%
next(row)
# Out:
# {'_id': ObjectId('6a58774ce723bf5d91382fb3'),
#  'SeriousDlqin2yrs': 0,
#  'RevolvingUtilizationOfUnsecuredLines': 0.08040863,
#  'age': 53,
#  'NumberOfTime30-59DaysPastDueNotWorse': 0,
#  'DebtRatio': 0.896689625,
#  'MonthlyIncome': 4500.0,
#  'NumberOfOpenCreditLinesAndLoans': 23,
#  'NumberOfTimes90DaysLate': 0,
#  'NumberRealEstateLoansOrLines': 2,
#  'NumberOfTime60-89DaysPastDueNotWorse': 0,
#  'NumberOfDependents': 0.0}

# %%
import boto3

# %%
s = boto3.client("s3",
                 aws_access_key_id=AWS_ACCESS_KEY_ID,
                 aws_secret_access_key=AWS_SECERET_ACCESS_KEY_ID)

# %%
s

# %%
response = s.list_buckets()

# %%
response
# Out:
# {'ResponseMetadata': {'RequestId': 'BYFFQ1XZ44G0AT2R',
#   'HostId': 'RSWk5zPG7ovfH0xLi1X6Ohskgyg2vNBic4TBRp199BgySTa6OSORJxI1/J4lfw8NpkVc3ZaMpztho4dO4YuI2S/voYpApBgi',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'RSWk5zPG7ovfH0xLi1X6Ohskgyg2vNBic4TBRp199BgySTa6OSORJxI1/J4lfw8NpkVc3ZaMpztho4dO4YuI2S/voYpApBgi',
#    'x-amz-request-id': 'BYFFQ1XZ44G0AT2R',
#    'date': 'Sun, 19 Jul 2026 03:56:13 GMT',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'churnprojectbucket',
#    'CreationDate': datetime.datetime(2026, 6, 6, 6, 40, 39, tzinfo=tzutc())},
#   {'Name': 'visaprojectbucket',
#    'CreationDate': datetime.datetime(2026, 5, 18, 7, 13, 20, tzinfo=tzutc())}],
#  'Owner': {'ID': 'd683345c1b8fbbc864f9449fc07735fd167043d4c55db5412d2b504596d0725b'}}

# %%
for bucket in response["Buckets"]:
    print(bucket["Name"],end=" ")
    print(bucket["CreationDate"])
    print()
# Out:
# churnprojectbucket 2026-06-06 06:40:39+00:00
#
# visaprojectbucket 2026-05-18 07:13:20+00:00

# %%
s.create_bucket(Bucket="creditriskprojectbucket",CreateBucketConfiguration={"LocationConstraint":region})
# Out:
# {'ResponseMetadata': {'RequestId': '8A5NVCZJTSHFEZTV',
#   'HostId': 'ebLJs3iqUskSS8rMAVjRqOCrzrukhUunmJBDJwWmjo3UygY4a3yYBjp1R9byRUir/p8XpexKjyvWmscVCHxqGRPFts6eGIYm',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'ebLJs3iqUskSS8rMAVjRqOCrzrukhUunmJBDJwWmjo3UygY4a3yYBjp1R9byRUir/p8XpexKjyvWmscVCHxqGRPFts6eGIYm',
#    'x-amz-request-id': '8A5NVCZJTSHFEZTV',
#    'date': 'Sun, 19 Jul 2026 04:11:14 GMT',
#    'location': 'http://creditriskprojectbucket.s3.amazonaws.com/',
#    'x-amz-bucket-arn': 'arn:aws:s3:::creditriskprojectbucket',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Location': 'http://creditriskprojectbucket.s3.amazonaws.com/'}

# %%
buckets = s.list_buckets()

# %%
buckets
# Out:
# {'ResponseMetadata': {'RequestId': 'KH3W44JWT7GV7A0T',
#   'HostId': '+ksDhGEM7/h/64eY3huZxjH6eei0qJVa6hnqcR2nLbMX9X1J6YPzqTppKfaZjNknxZqsN5dAi0C7XbvnWP7BNWHpTX7yXwmU',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': '+ksDhGEM7/h/64eY3huZxjH6eei0qJVa6hnqcR2nLbMX9X1J6YPzqTppKfaZjNknxZqsN5dAi0C7XbvnWP7BNWHpTX7yXwmU',
#    'x-amz-request-id': 'KH3W44JWT7GV7A0T',
#    'date': 'Sun, 19 Jul 2026 04:12:29 GMT',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'churnprojectbucket',
#    'CreationDate': datetime.datetime(2026, 6, 6, 6, 40, 39, tzinfo=tzutc())},
#   {'Name': 'creditriskprojectbucket',
#    'CreationDate': datetime.datetime(2026, 7, 19, 4, 11, 14, tzinfo=tzutc())},
#   {'Name': 'visaprojectbucket',
#    'CreationDate': datetime.datetime(2026, 5, 18, 7, 13, 20, tzinfo=tzutc())}],
# ...

# %%
for bucket in buckets["Buckets"]:
    print(bucket["Name"])
# Out:
# churnprojectbucket
# creditriskprojectbucket
# visaprojectbucket

# %%
s.upload_file("test.txt","creditriskprojectbucket","text")

# %%
objects = s.list_objects_v2(Bucket="creditriskprojectbucket")

# %%
objects
# Out:
# {'ResponseMetadata': {'RequestId': 'M0X4D885JNJ2A36M',
#   'HostId': 'fmYrI5EYuO8a1ybbHs2F05TxTTzMEJjyXw/d9hqVy8jZa/erWgnQWpnst0+c+STTxIc5xmkOwlGphudj0hJ4q12zNsZvl2+u',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'fmYrI5EYuO8a1ybbHs2F05TxTTzMEJjyXw/d9hqVy8jZa/erWgnQWpnst0+c+STTxIc5xmkOwlGphudj0hJ4q12zNsZvl2+u',
#    'x-amz-request-id': 'M0X4D885JNJ2A36M',
#    'date': 'Sun, 19 Jul 2026 04:17:39 GMT',
#    'x-amz-bucket-region': 'eu-north-1',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'IsTruncated': False,
#  'Contents': [{'Key': 'text',
#    'LastModified': datetime.datetime(2026, 7, 19, 4, 16, 31, tzinfo=tzutc()),
#    'ETag': '"21158172e961c9cca67a31013ca7783a"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'Size': 20,
#    'StorageClass': 'STANDARD'}],
#  'Name': 'creditriskprojectbucket',
#  'Prefix': '',
#  'MaxKeys': 1000,
#  'EncodingType': 'url',
#  'KeyCount': 1}

# %%
objects["Contents"][0]["Key"]
# Out:
# 'text'

# %%
s.download_file("creditriskprojectbucket","text","aws_text")

# %%
res = s.head_object(Bucket = "creditriskprojectbucket",
                    Key = "text")

# %%
res
# Out:
# {'ResponseMetadata': {'RequestId': '34PV4X35N3B7ES44',
#   'HostId': 'msLRpcUL7fQkEKxvQnCsbxuPL6DXIa179yJEe3JBotottRUW/VKFelK+fEC/whzxNFxlbLNljQRec6OE5zjPlnAGu9iT8JgT',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'msLRpcUL7fQkEKxvQnCsbxuPL6DXIa179yJEe3JBotottRUW/VKFelK+fEC/whzxNFxlbLNljQRec6OE5zjPlnAGu9iT8JgT',
#    'x-amz-request-id': '34PV4X35N3B7ES44',
#    'date': 'Sun, 19 Jul 2026 04:22:53 GMT',
#    'last-modified': 'Sun, 19 Jul 2026 04:16:31 GMT',
#    'etag': '"21158172e961c9cca67a31013ca7783a"',
#    'x-amz-server-side-encryption': 'AES256',
#    'accept-ranges': 'bytes',
#    'content-type': 'binary/octet-stream',
#    'content-length': '20',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'AcceptRanges': 'bytes',
#  'LastModified': datetime.datetime(2026, 7, 19, 4, 16, 31, tzinfo=tzutc()),
#  'ContentLength': 20,
#  'ETag': '"21158172e961c9cca67a31013ca7783a"',
#  'ContentType': 'binary/octet-stream',
#  'ServerSideEncryption': 'AES256',
# ...

# %%
s.delete_object(Bucket = "creditriskprojectbucket",
                Key = "text")
# Out:
# {'ResponseMetadata': {'RequestId': 'JMPPZEKAS575RXNN',
#   'HostId': '2e8+vFmfi8epnvhxgtf+QCjLyLeRcTK+hCBWD5HajytC+k32KOJpLNRoFUjenLFUTIIF7ZiyGBXG0FO54ZJhgW9O4m3vHUkv',
#   'HTTPStatusCode': 204,
#   'HTTPHeaders': {'x-amz-id-2': '2e8+vFmfi8epnvhxgtf+QCjLyLeRcTK+hCBWD5HajytC+k32KOJpLNRoFUjenLFUTIIF7ZiyGBXG0FO54ZJhgW9O4m3vHUkv',
#    'x-amz-request-id': 'JMPPZEKAS575RXNN',
#    'date': 'Sun, 19 Jul 2026 04:24:09 GMT',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0}}

# %%
churn_objects = s.list_objects_v2(Bucket = "churnprojectbucket", Prefix = "model.joblib" )

# %%
churn_objects
# Out:
# {'ResponseMetadata': {'RequestId': '5JHJHQ09J9B83RQE',
#   'HostId': 'WBO3lXQJCqsGJgzk+blrq6z3GkM+9yH9HSR8BczTwYAWque6lYEhTqQ1IprrmoLiJ5f4ZEuEluEieuK4wjvDt6RPwTxhxR7J',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'WBO3lXQJCqsGJgzk+blrq6z3GkM+9yH9HSR8BczTwYAWque6lYEhTqQ1IprrmoLiJ5f4ZEuEluEieuK4wjvDt6RPwTxhxR7J',
#    'x-amz-request-id': '5JHJHQ09J9B83RQE',
#    'date': 'Sun, 19 Jul 2026 05:30:26 GMT',
#    'x-amz-bucket-region': 'eu-north-1',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'IsTruncated': False,
#  'Contents': [{'Key': 'model.joblib',
#    'LastModified': datetime.datetime(2026, 6, 8, 4, 50, 38, tzinfo=tzutc()),
#    'ETag': '"92c577d60407f8ff6db7d7ae87ec6bcb"',
#    'ChecksumAlgorithm': ['CRC64NVME'],
#    'Size': 940902,
#    'StorageClass': 'STANDARD'}],
#  'Name': 'churnprojectbucket',
#  'Prefix': 'model.joblib',
#  'MaxKeys': 1000,
#  'EncodingType': 'url',
# ...

# %%
obj = churn_objects["Contents"][0]

# %%
obj
# Out:
# {'Key': 'model.joblib',
#  'LastModified': datetime.datetime(2026, 6, 8, 4, 50, 38, tzinfo=tzutc()),
#  'ETag': '"92c577d60407f8ff6db7d7ae87ec6bcb"',
#  'ChecksumAlgorithm': ['CRC64NVME'],
#  'Size': 940902,
#  'StorageClass': 'STANDARD'}

# %%
object_information = s.get_object(Bucket = "churnprojectbucket",
                                  Key = "model.joblib")

# %%
object_information
# Out:
# {'ResponseMetadata': {'RequestId': '9TJ1NZX81HNT0RTQ',
#   'HostId': 'y1dvWZENfgj/jxtrt5QIxAsta7W73zw0IbU4roEKrIN0ZlsQIUBQjjdzCKYTvutBi9ztF/IVRNPBsj+d9BI/h28jkOPaWaK1',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'y1dvWZENfgj/jxtrt5QIxAsta7W73zw0IbU4roEKrIN0ZlsQIUBQjjdzCKYTvutBi9ztF/IVRNPBsj+d9BI/h28jkOPaWaK1',
#    'x-amz-request-id': '9TJ1NZX81HNT0RTQ',
#    'date': 'Sun, 19 Jul 2026 05:47:30 GMT',
#    'last-modified': 'Mon, 08 Jun 2026 04:50:38 GMT',
#    'etag': '"92c577d60407f8ff6db7d7ae87ec6bcb"',
#    'x-amz-server-side-encryption': 'AES256',
#    'accept-ranges': 'bytes',
#    'content-type': 'binary/octet-stream',
#    'content-length': '940902',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'AcceptRanges': 'bytes',
#  'LastModified': datetime.datetime(2026, 6, 8, 4, 50, 38, tzinfo=tzutc()),
#  'ContentLength': 940902,
#  'ETag': '"92c577d60407f8ff6db7d7ae87ec6bcb"',
#  'ContentType': 'binary/octet-stream',
#  'ServerSideEncryption': 'AES256',
# ...

# %%
from io import BytesIO

# %%
bytes = object_information["Body"].read()

# %%
stream = BytesIO(bytes)

# %%
stream.read()
# Out:
# b'\x80\x04\x95\xe4\x07\x00\x00\x00\x00\x00\x00\x8c\x16churn.entity.estimator\x94\x8c\nchurnmodel\x94\x93\x94)\x81\x94}\x94(\x8c\x11preprocessing_obj\x94\x8c#sklearn.compose._column_transformer\x94\x8c\x11ColumnTransformer\x94\x93\x94)\x81\x94}\x94(\x8c\x0ctransformers\x94]\x94(\x8c\x11numerical_columns\x94\x8c\x10sklearn.pipeline\x94\x8c\x08Pipeline\x94\x93\x94)\x81\x94}\x94(\x8c\x05steps\x94]\x94(\x8c\x07imputer\x94\x8c\x14sklearn.impute._base\x94\x8c\rSimpleImputer\x94\x93\x94)\x81\x94}\x94(\x8c\x0emissing_values\x94G\x7f\xf8\x00\x00\x00\x00\x00\x00\x8c\radd_indicator\x94\x89\x8c\x13keep_empty_features\x94\x89\x8c\x08strategy\x94\x8c\x06median\x94\x8c\nfill_value\x94N\x8c\x07verbose\x94\x8c\ndeprecated\x94\x8c\x04copy\x94\x88\x8c\x10_sklearn_version\x94\x8c\x051.2.2\x94ub\x86\x94\x8c\x06scaler\x94\x8c\x1bsklearn.preprocessing._data\x94\x8c\x0eStandardScaler\x94\x93\x94)\x81\x94}\x94(\x8c\twith_mean\x94\x88\x8c\x08with_std\x94\x88h#\x88h$h%ub\x86\x94e\x8c\x06memory\x94N\x8c\x07verbo
# ...
